# %% [markdown]
# ## Práctica 1
#
# Luego de registrarse en el sitio de Kaggle, realice la siguiente práctica:
#
# 1.   Descargue el archivo CSV asociado en el siguiente enlace: [Disease Symptoms and Patient Profile Dataset](https://www.kaggle.com/datasets/uom190346a/disease-symptoms-and-patient-profile-dataset?resource=download).
# 2.   Cargue dicho archivo en su ambiente de trabajo ya sea Google Colaboratory o el supercomputador Kabré. Asegúrese que este fue cargado correctamente.
# 3.   Añada una celda de código que despliegue el contenido del CSV.
# 4.   ¿Cúales son las variables que contiene este conjunto de datos? Utilice una celda de texto para hacer la descripción del set de datos.

# %% [markdown]
# ## Dylan Navarro Badilla
# ### Práctica 1

# %% [markdown]
# ### Primero se importa el drive y se localiza la ruta.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
! pwd
# Out:
# /content

# %% [markdown]
# ### Ahora se utiliza el comando `%cat` para desplegar el contenido del csv.

# %%
# %cat /content/Disease_symptom_and_patient_profile_dataset.csv
# Out:
# Disease,Fever,Cough,Fatigue,Difficulty Breathing,Age,Gender,Blood Pressure,Cholesterol Level,Outcome Variable
# Influenza,Yes,No,Yes,Yes,19,Female,Low,Normal,Positive
# Common Cold,No,Yes,Yes,No,25,Female,Normal,Normal,Negative
# Eczema,No,Yes,Yes,No,25,Female,Normal,Normal,Negative
# Asthma,Yes,Yes,No,Yes,25,Male,Normal,Normal,Positive
# Asthma,Yes,Yes,No,Yes,25,Male,Normal,Normal,Positive
# Eczema,Yes,No,No,No,25,Female,Normal,Normal,Positive
# Influenza,Yes,Yes,Yes,Yes,25,Female,Normal,Normal,Positive
# Influenza,Yes,Yes,Yes,Yes,25,Female,Normal,Normal,Positive
# Hyperthyroidism,No,Yes,No,No,28,Female,Normal,Normal,Negative
# Hyperthyroidism,No,Yes,No,No,28,Female,Normal,Normal,Negative
# Asthma,Yes,No,No,Yes,28,Male,High,Normal,Positive
# Allergic Rhinitis,No,Yes,Yes,No,29,Female,Normal,Low,Negative
# Anxiety Disorders,No,Yes,No,No,29,Female,Normal,High,Negative
# Common Cold,No,No,No,No,29,Female,Low,Normal,Negative
# Diabetes,No,No,No,No,29,Male,Low,Normal,Negative
# ...

# %% [markdown]
# ### Para una mejor visualización de los datos, se utiliza el siguiente comando:

# %%
# %cat /content/Disease_symptom_and_patient_profile_dataset.csv | head -n 20 | column -t -s ,
# Out:
# Disease               Fever  Cough  Fatigue  Difficulty Breathing  Age  Gender  Blood Pressure  Cholesterol Level  Outcome Variable
# Influenza             Yes    No     Yes      Yes                   19   Female  Low             Normal             Positive
# Common Cold           No     Yes    Yes      No                    25   Female  Normal          Normal             Negative
# Eczema                No     Yes    Yes      No                    25   Female  Normal          Normal             Negative
# Asthma                Yes    Yes    No       Yes                   25   Male    Normal          Normal             Positive
# Asthma                Yes    Yes    No       Yes                   25   Male    Normal          Normal             Positive
# Eczema                Yes    No     No       No                    25   Female  Normal          Normal             Positive
# ...

# %% [markdown]
# ### Las variables que contiene este set de datos son las siguientes:
# Disease: tipo de enfermedad \
# Fever: booleano que indica si la persona tiene fiebre \
# Cough: booleano que indica si la persona tiene tos \
# Fatigue: booleano que indica si la persona tiene fatiga \
# Difficulty Breathing: booleano que indica si la persona tiene dificultad para respirar \
# Age: int que indica la edad \
# Gender: genero \
# Blood Pressure: presión sanguínea \
# Cholesterol level: nivel del colesterol \
# Outcome Variable: indica si la persona es positiva o negativa
